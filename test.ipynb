# %%
import pandas as pd
df = pd.read_csv("returns_sustainability_dataset.csv")
print(df.groupby("Return_Status")[["CO2_Emissions", "Packaging_Waste"]].mean())
# Out:
#                CO2_Emissions  Packaging_Waste
# Return_Status
# Not Returned        1.502254         0.600958
# Returned            1.494828         0.596000

# %%
print(df.groupby("Return_Status")[["Return_Cost", "Profit_Loss"]].mean())
# Out:
#                Return_Cost  Profit_Loss
# Return_Status
# Not Returned           0.0  2384.673387
# Returned             200.0  2123.718499
